# %% [markdown]
# **Task 06: Modifying RDF(s)**

# %%
# !pip install rdflib
github_storage = "https://raw.githubusercontent.com/FacultadInformatica-LinkedData/Curso2024-2025/master/Assignment4/course_materials"
# Out:
# Collecting rdflib
#   Downloading rdflib-7.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib) (3.1.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)
# Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 7.1 MB/s eta 0:00:00
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: isodate, rdflib
# Successfully installed isodate-0.6.1 rdflib-7.0.0

# %% [markdown]
# Read the RDF file as shown in class

# %%
from rdflib import Graph, Namespace, Literal
from rdflib.namespace import RDF, RDFS
g = Graph()
g.namespace_manager.bind('ns', Namespace("http://somewhere#"), override=False)
g.namespace_manager.bind('vcard', Namespace("http://www.w3.org/2001/vcard-rdf/3.0#"), override=False)
g.parse(github_storage+"/rdf/example5.rdf", format="xml")
# Out:
# <Graph identifier=N9981c441f1e741ff91897c4ef99cdb2a (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# Create a new class named Researcher

# %%
ns = Namespace("http://somewhere#")
g.add((ns.Researcher, RDF.type, RDFS.Class))
for s, p, o in g:
  print(s,p,o)
# Out:
# http://somewhere#JohnSmith http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/FN Sara Jones
# http://somewhere#Person http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Family Smith
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/FN John Smith
# http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Property
# http://somewhere#Researcher http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/Given Sara
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/Family Jones
# http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://somewhere#SaraJones http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person
# http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Given John

# %% [markdown]
# **TASK 6.1: Create a new class named "University"**

# %%
# TO DO
g.add((ns.University, RDF.type, RDFS.Class))

# Visualize the results
for s, p, o in g:
  print(s,p,o)
# Out:
# http://somewhere#JohnSmith http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/FN Sara Jones
# http://somewhere#Person http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Family Smith
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/FN John Smith
# http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Property
# http://somewhere#Researcher http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://somewhere#University http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/Given Sara
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/Family Jones
# http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://somewhere#SaraJones http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person
# http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Given John

# %% [markdown]
# **TASK 6.2: Add "Researcher" as a subclass of "Person"**

# %%
# TO DO
g.add((ns.Researcher, RDFS.subClassOf, ns.Person))

# Visualize the results
for s, p, o in g:
  print(s,p,o)
# Out:
# http://somewhere#Researcher http://www.w3.org/2000/01/rdf-schema#subClassOf http://somewhere#Person
# http://somewhere#JohnSmith http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/FN Sara Jones
# http://somewhere#Person http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Family Smith
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/FN John Smith
# http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Property
# http://somewhere#Researcher http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://somewhere#University http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/Given Sara
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/Family Jones
# http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://somewhere#SaraJones http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person
# http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Given John

# %% [markdown]
# **TASK 6.3: Create a new individual of Researcher named "Jane Smithers"**

# %%
# TO DO
vcard = Namespace("http://www.w3.org/2001/vcard-rdf/3.0#")
g.add((ns.JaneSmithers, vcard.FN, Literal("Jane Smithers")))
g.add((ns.JaneSmithers, RDF.type, ns.Researcher))

# Visualize the results
for s, p, o in g:
  print(s,p,o)
# Out:
# http://somewhere#Researcher http://www.w3.org/2000/01/rdf-schema#subClassOf http://somewhere#Person
# http://somewhere#JohnSmith http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/FN Sara Jones
# http://somewhere#Person http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Family Smith
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/FN John Smith
# http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Property
# http://somewhere#Researcher http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://somewhere#University http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/Given Sara
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/Family Jones
# http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://somewhere#SaraJones http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person
# http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Given John
# http://somewhere#JaneSmithers http://www.w3.org/2001/vcard-rdf/3.0#FN Jane Smithers
# http://somewhere#JaneSmithers http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Researcher

# %% [markdown]
# **TASK 6.4: Add to the individual JaneSmithers the email address, fullName, given and family names. Use the https://schema.org vocabulary**

# %%
# TO DO
schema = Namespace("https://schema.org/")
g.add((schema.JaneSmitehers, vcard.EMAIL, Literal("janesmithers@example.com")))
g.add((schema.JaneSmitehers, vcard.FN, Literal("Jane Smithers")))
g.add((schema.JaneSmitehers, vcard.Given, Literal("Jane")))
g.add((schema.JaneSmitehers, vcard.Family, Literal("Smithers")))

# Visualize the results
for s, p, o in g:
    print(s, p, o)
# Out:
# https://schema.org/JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#FN Jane Smithers
# http://somewhere#Researcher http://www.w3.org/2000/01/rdf-schema#subClassOf http://somewhere#Person
# http://somewhere#JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#EMAIL janesmithers@example.com
# http://somewhere#JohnSmith http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/FN Sara Jones
# http://somewhere#Person http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# https://schema.org/JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#Given Jane
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Family Smith
# https://schema.org/JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#EMAIL janesmithers@example.com
# http://somewhere#JaneSmithers http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Researcher
# https://schema.org/JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#Family Smithers
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/FN John Smith
# http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Property
# http://somewhere#Researcher http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://somewhere#University http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/Given Sara
# http://somewhere#JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#FN Jane Smithers
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/Family Jones
# http://somewhere#JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#GIVENNAME Smithers
# http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://somewhere#JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#NAME Jane
# http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://somewhere#SaraJones http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person
# http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Given John
# http://somewhere#JaneSmithers http://www.w3.org/2001/vcard-rdf/3.0#FN Jane Smithers
# http://somewhere#JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#Given Jane
# http://somewhere#JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#Family Smithers

# %% [markdown]
# **TASK 6.5: Add UPM as the university where John Smith works. Use the "https://example.org/ namespace**

# %%
# TO DO
ex = Namespace("http://example.org/")
upm = ex.UPM
g.add((upm, RDF.type, ns.University))
g.add((ns.JohnSmith, ex.worksAt, upm))

# Visualize the results
for s, p, o in g:
    print(s, p, o)
# Out:
# http://somewhere#Researcher http://www.w3.org/2000/01/rdf-schema#subClassOf http://somewhere#Person
# http://somewhere#JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#EMAIL janesmithers@example.com
# http://somewhere#JohnSmith http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person
# http://somewhere#Person http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# https://schema.org/JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#Given Jane
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Family Smith
# https://schema.org/JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#EMAIL janesmithers@example.com
# https://schema.org/JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#Family Smithers
# http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://example.org/UPM http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#University
# http://somewhere#JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#Family Smithers
# http://somewhere#University http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/Given Sara
# http://somewhere#JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#FN Jane Smithers
# http://somewhere#JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#GIVENNAME Smithers
# http://somewhere#SaraJones http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person
# http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://somewhere#JaneSmithers http://www.w3.org/2001/vcard-rdf/3.0#FN Jane Smithers
# https://schema.org/JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#FN Jane Smithers
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/FN Sara Jones
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/FN John Smith
# http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Property
# http://somewhere#Researcher http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/Family Jones
# http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://somewhere#JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#NAME Jane
# http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Given John
# http://somewhere#JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#Given Jane
# http://somewhere#JaneSmithers http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Researcher
# http://somewhere#JohnSmith http://example.org/worksAt http://example.org/UPM

# %% [markdown]
# **Task 6.6: Add that Jown knows Jane using the FOAF vocabulary. Make sure the relationship exists.**

# %%
# TO DO
from rdflib import FOAF
g.add((ns.JohnSmith, FOAF.knows, schema.JaneSmitehers))

# Visualize the results
for s, p, o in g:
    print(s, p, o)
# Out:
# http://somewhere#Researcher http://www.w3.org/2000/01/rdf-schema#subClassOf http://somewhere#Person
# http://somewhere#JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#EMAIL janesmithers@example.com
# http://somewhere#JohnSmith http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person
# http://somewhere#Person http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# https://schema.org/JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#Given Jane
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Family Smith
# https://schema.org/JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#EMAIL janesmithers@example.com
# https://schema.org/JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#Family Smithers
# http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://example.org/UPM http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#University
# http://somewhere#JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#Family Smithers
# http://somewhere#University http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/Given Sara
# http://somewhere#JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#FN Jane Smithers
# http://somewhere#JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#GIVENNAME Smithers
# http://somewhere#SaraJones http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person
# http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://somewhere#JaneSmithers http://www.w3.org/2001/vcard-rdf/3.0#FN Jane Smithers
# https://schema.org/JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#FN Jane Smithers
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/FN Sara Jones
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/FN John Smith
# http://somewhere#JohnSmith http://xmlns.com/foaf/0.1/knows https://schema.org/JaneSmitehers
# http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Property
# http://somewhere#Researcher http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/Family Jones
# http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://somewhere#JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#NAME Jane
# http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Given John
# http://somewhere#JaneSmitehers http://www.w3.org/2001/vcard-rdf/3.0#Given Jane
# http://somewhere#JaneSmithers http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Researcher
# http://somewhere#JohnSmith http://example.org/worksAt http://example.org/UPM
